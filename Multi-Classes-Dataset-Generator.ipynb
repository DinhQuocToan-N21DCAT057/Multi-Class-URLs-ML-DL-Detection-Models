# %%
# !pip install python-whois python-Levenshtein tldextract requests dnspython pyquery beautifulsoup4 tqdm pandas

# %%
# !git clone https://github.com/DinhQuocToan-N21DCAT057/Multi-Labels-URLs-ML-DL-Detection-Models
# Out:
# Cloning into 'Multi-Labels-URLs-ML-DL-Detection-Models'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 112 (delta 51), reused 69 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 8.07 MiB | 16.92 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %% [markdown]
# Lưu ý: Sau khi clone repo từ github về upload file malicious_phish.csv vào đường dẫn sau: /content/Multi-Labels-URLs-ML-DL-Detection-Models/

# %%
#Chạy thử với 10 url ngẫu nhiên
# !python /content/Multi-Labels-URLs-ML-DL-Detection-Models/scripts/test.py
# Out:
# ...
# [1/10] Extracting features for:
#   URL  : http://www.fdstpp.cn/steam-pubg
#   Label: phishing
#   Extracting features: 100% 91/91 [00:03<00:00, 29.95feature/s]
#   URL 'http://www.fdstpp.cn/steam-pubg' took '7.88' seconds to extract
# ...
# [2/10] Extracting features for:
#   URL  : chucksblog.typepad.com/chucks_blog/
#   Label: phishing
#   Extracting features: 100% 91/91 [00:03<00:00, 29.08feature/s]
#   URL 'chucksblog.typepad.com/chucks_blog/' took '6.44' seconds to extract
# ...
# [3/10] Extracting features for:
#   URL  : '9d345009-a-62cb3a1a-s-sites.googlegroups.com/site/stickamcomlogindo/login.html?amp\%3Battredirects=1&amp;attachauth=ANoY7cqobOnf4AV1u1Hxjt9bDuHbgyQp5FRIAR2kCC2brWw9y8NxxUlDnPNN0bcpXdLMvaHhsuavw2LkXNJwmmBrJgYJXOsAreMdE2Z2jToZOYKXWMgDT3KAShNqQeogzN31CIe2RSWk6wJPjcaIAX0U967suvjur4FUfPSFBDOGoDL2_NMZsh77cQkvTsqKUmjVWnsCcboKfldE4diJHpsSFgkClLeHLw\%3D\%3D&amp;attredirects=0'
#   Label: benign
#   Extracting features: 100% 91/91 [00:01<00:00, 56.41feature/s]
# ...

# %%
#Chạy dataset
# !python /content/Multi-Labels-URLs-ML-DL-Detection-Models/scripts/dataset_gen.py --file url_malware.csv --start_idx 20000 --end_idx 22000
# Out:
# Extracting urls from 20000 to 22000 (2000)
# ...
# [1/2000] (global idx: 20000) Extracting features for:
#   URL  : http://81.42.249.132:1080/R-02-RADIOLE/16%2004%202025/info.zip
#   Label: malware
# 2025-07-23 08:53:06,610 - WARNING - Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   Extracting features: 100% 91/91 [00:01<00:00, 78.47feature/s]
#   URL 'http://81.42.249.132:1080/R-02-RADIOLE/16%2004%202025/info.zip' took '66.33' seconds to extract
# ...
# [2/2000] (global idx: 20001) Extracting features for:
#   URL  : http://58.22.95.207:6868/20240103%E8%8B%B1%E8%AF%AD%E5%90%AC%E8%AF%B4%E6%9C%9F%E6%9C%AB%E5%BD%95%E9%9F%B3/%E5%BD%B1%E8%A7%86%E6%8A%80%E6%9C%AF%E7%8F%AD/119%E9%A9%AC%E9%9B%AF%E5%A9%B7-%E6%97%A0/AV.lnk
#   Label: malware
#   Extracting features: 100% 91/91 [00:00<00:00, 105.32feature/s]
# ...
